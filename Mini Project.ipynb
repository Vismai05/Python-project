# %%
class Error(Exception):
    pass
class ScoreError(Error):
    pass
class InputError(Error):
    pass

def batfirst():
    o=12
    s=0
    w=0
    wl=3
    print("\t\t\t*******First Innings Started*******")
    while o>0:
        bo=round(random.random()*6)
        hit=int(input("\nEnter number to Score Runs: "))
        try:
            if hit>6 or hit==5:
                raise ScoreError
            elif bo==hit:
                print("You are OUT")
                s=s+0
                w=w+1
                wl=wl-1
                print("(",s,"/",w,")")
                if wl==0:
                    break
                o=o-1
                print(o,"Balls and",wl,"Wickets Left")
            elif bo==5:
                print("!!No Ball!!",
                      "\nIts a FreeHit")
                s=s+hit+1
                print("(",s,"/",w,")")
                print(o,"Balls and",wl,"Wickets Left")
                print("\n********FreeHit Ball********")
                hit=[1,2,3,4,6]
                h=random.choice(hit)
                if h==4:
                    print("You Hit a Four")
                    s=s+h
                    print("(",s,"/",w,")")
                    o=o-1
                    print(o,"Balls and",wl,"Wickets Left")
                elif h==6:
                    print("You Hit a Six")
                    s=s+h
                    print("(",s,"/",w,")")
                    o=o-1
                    print(o,"Balls and",wl,"Wickets Left")
                else:
                    print("You Ran",h,"Runs")
                    s=s+h
                    print("(",s,"/",w,")")
                    o=o-1
                    print(o,"Balls and",wl,"Wickets Left")
            elif hit==4:
                print("You Hit a Four")
                s=s+hit
                print("(",s,"/",w,")")
                o=o-1
                print(o,"Balls and",wl,"Wickets Left")
            elif hit==6:
                print("You Hit a Six")
                s=s+hit
                print("(",s,"/",w,")")
                o=o-1
                print(o,"Balls and",wl,"Wickets Left")
            elif hit!=bo:
                print("You scored",hit,"Runs")
                s=s+hit
                print("(",s,"/",w,")")
                o=o-1
                print(o,"Balls and",wl,"Wickets Left")
        except ScoreError:
            print("We cannot score this much runs in one ball")
        except:
            print("Invaild input")
    print("\t\t\t*******First Innings Ended*******")
    s=s+1
    o=12
    s1=0
    w=0
    wl=3
    print("\n\n\t\t\t*******Second Innings Started*******")
    print("\nComputer needs to score",s,"Runs in 12 balls")
    while o>0:
        bo=round(random.random()*6)
        ba=int(input("\nEnter number to Ball: "))
        try:
            if bo==ba:
                print("You Took a Wicket")
                s1=s1+0
                w=w+1
                wl=wl-1
                print("(",s1,"/",w,")")
                if wl==0:
                    break
                o=o-1
                print("Computer needs",s-s1,"Runs in",o,"Balls to Win")
            elif ba==5:
                print("!!No Ball!!",
                      "\nIts a FreeHit")
                s1=s1+hit+1
                print("(",s1,"/",w,")")
                if s1==s:
                    print("Computer Won The Match by",wl,"Wickets")
                    break
                print(o,"Balls and",wl,"Wickets Left")
                print("\n********FreeHit Ball********")
                hit=[1,2,3,4,6]
                h=random.choice(hit)
                if h==4:
                    print("Computer Hit a Four")
                    s1=s1+h
                    print("(",s1,"/",w,")")
                    if s1==s:
                        print("Computer Won The Match by",wl,"Wickets")
                        break
                    o=o-1
                    print("Computer needs",s-s1,"Runs in",o,"Balls to Win")
                elif h==6:
                    print("Computer Hit a Six")
                    s1=s1+h
                    print("(",s1,"/",w,")")
                    if s1==s:
                        print("Computer Won The Match by",wl,"Wickets")
                        break
                    o=o-1
                    print("Computer needs",s-s1,"Runs in",o,"Balls to Win")
                else:
                    print("Computer Ran",h,"Runs")
                    s1=s1+h
                    print("(",s1,"/",w,")")
                    if s1==s:
                        print("Computer Won The Match by",wl,"Wickets")
                        break
                    o=o-1
                    print("Computer needs",s-s1,"Runs in",o,"Balls to Win")
            elif bo==4:
                print("Computer Hit a Four")
                s1=s1+bo
                if s1==s:
                    print("Computer Won The Match by",wl,"Wickets")
                    break
                print("(",s1,"/",w,")")
                o=o-1
                print("Computer needs",s-s1,"Runs in",o,"Balls to Win")
            elif bo==6:
                print("Computer Hit a Six")
                s1=s1+bo
                if s1==s:
                    print("Computer Won The Match by",wl,"Wickets")
                    break
                print("(",s1,"/",w,")")
                o=o-1
                print("Computer needs",s-s1,"Runs in",o,"Balls to Win")
            elif bo==5:
                print("Dead Ball")
            else:
                print("Computer scored",bo,"Runs")
                s1=s1+bo
                print("(",s1,"/",w,")")
                if s1==s:
                    print("Computer Won The Match by",wl,"Wickets")
                    break
                o=o-1
                print("Computer needs",s-s1,"Runs in",o,"Balls to Win")
        except:
            print("Invalid input")
    if (s-1)==s1:
        print("Match Draw")
    elif s>s1:
        print("Congratulations You Won the Match by",s-s1,"Runs")

def ballfirst():
    o=12
    s1=0
    w=0
    wl=3
    print("\t\t\t*******First Innings Started*******")
    while o>0:
        bo=round(random.random()*6)
        ba=int(input("\nEnter number to Ball: "))
        try:
            if bo==ba:
                print("You Took a Wicket")
                s1=s1+0
                w=w+1
                wl=wl-1
                print("(",s1,"/",w,")")
                if wl==0:
                    break
                o=o-1
                print(o,"Balls and",wl,"Wickets Left")
            elif ba==5:
                print("!!No Ball!!",
                      "\nIts a FreeHit")
                s1=s1+bo+1
                print("(",s1,"/",w,")")
                print(o,"Balls and",wl,"Wickets Left")
                print("\n********FreeHit Ball********")
                hit=[1,2,3,4,6]
                h=random.choice(hit)
                if h==4:
                    print("Computer Hit a Four")
                    s1=s1+h
                    print("(",s1,"/",w,")")
                    o=o-1
                    print(o,"Balls and",wl,"Wickets Left")
                elif h==6:
                    print("Computer Hit a Six")
                    s1=s1+h
                    print("(",s1,"/",w,")")
                    o=o-1
                    print(o,"Balls and",wl,"Wickets Left")
                else:
                    print("Computer Ran",h,"Runs")
                    s1=s1+h
                    print("(",s1,"/",w,")")
                    o=o-1
                    print(o,"Balls and",wl,"Wickets Left")
            elif bo==4:
                print("Computer Hit a Four")
                s1=s1+bo
                print("(",s1,"/",w,")")
                o=o-1
                print(o,"Balls and",wl,"Wickets Left")
            elif bo==6:
                print("Computer Hit a Six")
                s1=s1+bo
                print("(",s1,"/",w,")")
                o=o-1
                print(o,"Balls and",wl,"Wickets Left")
            elif bo==5:
                print("Dead Ball")
            else:
                print("Computer scored",bo,"Runs")
                s1=s1+bo
                print("(",s1,"/",w,")")
                o=o-1
                print(o,"Balls and",wl,"Wickets Left")
        except:
            print("Invalid input")
    print("\t\t\t*******First Innings Ended*******")
    s1=s1+1
    o=12
    s=0
    w=0
    wl=3
    print("\n\n\t\t\t*******Second Innings Started*******")
    print("\nYou need to score",s1,"Runs in 12 balls")
    while o>0:
        bo=round(random.random()*6)
        hit=int(input("\nEnter number to Score Runs: "))
        try:
            if hit>6 or hit==5:
                raise ScoreError
            elif bo==hit:
                print("You are OUT")
                s=s+0
                w=w+1
                wl=wl-1
                print("(",s,"/",w,")")
                if wl==0:
                    break
                o=o-1
                print("You need",s1-s,"Runs in",o,"Balls to Win")
            elif bo==5:
                print("!!No Ball!!",
                      "\nIts a FreeHit")
                s=s+hit+1
                print("(",s,"/",w,")")
                if s==s1:
                    print("Congratulations You Won the match by",wl,"Wickets")
                    break
                print("You need",s1-s,"Runs in",o,"Balls to Win")
                print("\n********FreeHit Ball********")
                hit=[1,2,3,4,6]
                h=random.choice(hit)
                if h==4:
                    print("You Hit a Four")
                    s=s+h
                    print("(",s,"/",w,")")
                    if s==s1:
                        print("Congratulations You Won the match by",wl,"Wickets")
                        break
                    o=o-1
                    print("You need",s1-s,"Runs in",o,"Balls to Win")
                elif h==6:
                    print("You Hit a Six")
                    s=s+h
                    print("(",s,"/",w,")")
                    if s==s1:
                        print("Congratulations You Won the match by",wl,"Wickets")
                        break
                    o=o-1
                    print("You need",s1-s,"Runs in",o,"Balls to Win")
                else:
                    print("You Ran",h,"Runs")
                    s=s+h
                    print("(",s,"/",w,")")
                    if s==s1:
                        print("Congratulations You Won the match by",wl,"Wickets")
                        break
                    o=o-1
                    print("You need",s1-s,"Runs in",o,"Balls to Win")
            elif hit==4:
                print("You Hit a Four")
                s=s+hit
                print("(",s,"/",w,")")
                if s==s1:
                    print("Congratulations You Won the match by",wl,"Wickets")
                    break
                o=o-1
                print("You need",s1-s,"Runs in",o,"Balls to Win")
            elif hit==6:
                print("You Hit a Six")
                s=s+hit
                print("(",s,"/",w,")")
                if s==s1:
                    print("Congratulations You Won the match by",wl,"Wickets")
                    break
                o=o-1
                print("You need",s1-s,"Runs in",o,"Balls to Win")
            else:
                print("You scored",hit,"Runs")
                s=s+hit
                print("(",s,"/",w,")")
                if s==s1:
                    print("Congratulations You Won the match by",wl,"Wickets")
                    break
                o=o-1
                print("You need",s1-s,"Runs in",o,"Balls to Win")
        except ScoreError:
            print("We cannot score this much runs in one ball")
        except:
            print("Invaild input")
    if (s1-1)==s:
        print("Match Draw")
    elif s1>s:
        print("Computer Won the Match by",s1-s,"Runs")
    
    
print("\t\t\t\t\t\tTime For Toss")
import random
import re
coun=0

while coun<1:
    toss=["Heads","Tails"]
    result=random.choice(toss)
    choice=input("Enter H for Heads or T for Tails: ")
    ch1=re.search("^(?=.*[HTht]{1}$)",choice)
    try:
        if ch1:
            coun+=1
            if choice.upper()=="H" and result=="Heads":
                print("\nYou won the toss")
                choose=int(input("Enter 0 to Bat and 1 to Ball: "))
                if choose==0:
                    print("You chose to Bat first")
                    batfirst()
                elif choose==1:
                    print("You chose to Ball first")
                    ballfirst()
            elif choice.upper()=="T" and result=="Tails":
                print("\nYou won the toss")
                choose=int(input("Enter 0 to Bat and 1 to Ball: "))
                if choose==0:
                    print("You chose to Bat first")
                    batfirst()
                elif choose==1:
                    print("You chose to Ball first")
                    ballfirst()
            else:
                print("\nYou loss the toss")
                choose=round(random.random())
                if choose==0:
                    print("Computer chose to Bat first")
                    ballfirst()
                elif choose==1:
                    print("Computer chose to Ball first")
                    batfirst()
        else:
            raise InputError
    except InputError:
        print("Invalid input")
# Out:
# 						Time For Toss
# Enter H for Heads or T for Tails: t
#
# You loss the toss
# Computer chose to Bat first
# 			*******First Innings Started*******
#
# Enter number to Ball: 4
# Dead Ball
#
# Enter number to Ball: 6
# Computer Hit a Four
# ( 4 / 0 )
# 11 Balls and 3 Wickets Left
#
# Enter number to Ball: 4
# Dead Ball
#
# Enter number to Ball: 6
# Computer scored 1 Runs
# ( 5 / 0 )
# 10 Balls and 3 Wickets Left
#
# Enter number to Ball: 4
# Computer scored 1 Runs
# ( 6 / 0 )
# 9 Balls and 3 Wickets Left
#
# Enter number to Ball: 6
# Computer scored 3 Runs
# ( 9 / 0 )
# 8 Balls and 3 Wickets Left
#
# Enter number to Ball: 4
# You Took a Wicket
# ( 9 / 1 )
# 7 Balls and 2 Wickets Left
#
# Enter number to Ball: 6
# Computer Hit a Four
# ( 13 / 1 )
# 6 Balls and 2 Wickets Left
#
# Enter number to Ball: 4
# Computer scored 3 Runs
# ( 16 / 1 )
# 5 Balls and 2 Wickets Left
#
# Enter number to Ball: 6
# Dead Ball
#
# Enter number to Ball: 4
# Computer scored 1 Runs
# ( 17 / 1 )
# ...
